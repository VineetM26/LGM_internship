# %% [markdown]
# <a href="https://colab.research.google.com/github/VineetM26/LGM_internship/blob/main/img2sktch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Image to pencil sketch conversion using opencv library of python

# %% [markdown]
# importing library

# %%
pip install opencv-python

# %%
from google.colab.patches import cv2
old_image=cv2.imread("/content/drive/MyDrive/depositphotos_56467811-stock-photo-happy-golden-retriever-puppy.jpg")
old_image.shape
# Out:
# (400, 600, 3)

# %%
from google.colab.patches import cv2_imshow

# %% [markdown]
# resizing the image

# %%
import cv2
image=cv2.resize(old_image,(520,520))
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=520x520 at 0x7F9085C42CD0>
# -1

# %%
gray_img=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=520x520 at 0x7F9084368310>
# -1

# %%
inverted_img=255- gray_img
cv2_imshow(inverted_img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=520x520 at 0x7F9084374410>
# -1

# %%
blurred=cv2.GaussianBlur(inverted_img,(21,21),0)
cv2_imshow(blurred)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=520x520 at 0x7F9084368810>
# -1

# %%
from google.colab.patches import cv2_imshow
inverted_blurred=255 - blurred
pencil_sketch=cv2.divide(gray_img,inverted_blurred,scale=256.0)
cv2_imshow(pencil_sketch)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=520x520 at 0x7F908F46CFD0>
# -1
